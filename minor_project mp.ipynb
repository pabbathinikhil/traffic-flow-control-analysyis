# %% [markdown]
# # Using Ultralytics YOLOv8, ByteTrack and Supervision for tracking and counting
#
#
#
#     Detection with yolov8
#
#     Tracking with BoT-SORT
#
#     Counting using supervision

# %%
# !pip install ultralytics

import ultralytics
ultralytics.__version__
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 750.4/750.4 kB 10.4 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# ...

# %%
# !pip install supervision
import supervision
print("supervision.__version__:", supervision.__version__)
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.1/97.1 kB 1.9 MB/s eta 0:00:00
# ...
# supervision.__version__: 0.19.0

# %%
import torch
torch.__version__
# Out:
# '2.2.1+cu121'

# %% [markdown]
# # Detection

# %%
from ultralytics import YOLO

# Load a pretrained YOLOv8n model
model = YOLO('yolov8n.pt')

# Run inference on 'bus.jpg' with arguments
model.predict(source="/content/d.mp4", save=True, imgsz=320, conf=0.5)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/687) /content/d.mp4: 192x320 3 cars, 50.2ms
# video 1/1 (frame 2/687) /content/d.mp4: 192x320 3 cars, 45.0ms
# video 1/1 (frame 3/687) /content/d.mp4: 192x320 4 cars, 39.8ms
# video 1/1 (frame 4/687) /content/d.mp4: 192x320 4 cars, 35.9ms
# video 1/1 (frame 5/687) /content/d.mp4: 192x320 4 cars, 36.0ms
# video 1/1 (frame 6/687) /content/d.mp4: 192x320 3 cars, 36.3ms
# ...

# %% [markdown]
# # Tracking

# %%
from ultralytics import YOLO

# Configure the tracking parameters and run the tracker
model = YOLO('yolov8n.pt')

results = model.track(source="/content/d.mp4",conf=0.3, iou=0.5, save=True, tracker="bytetrack.yaml")
# Out:
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 12.2 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 7.1s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
#
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/687) /content/d.mp4: 384x640 7 cars, 159.2ms
# ...

# %% [markdown]
# # Tracking and counting  - 1 line

# %%
import cv2
from collections import defaultdict
import supervision as sv
from ultralytics import YOLO

# Load the YOLOv8 model
model = YOLO('yolov8n.pt')

# Set up video capture
cap = cv2.VideoCapture("/content/d.mp4")

# Define the line coordinates
START = sv.Point(182, 254)
END = sv.Point(462, 254)
#Define for side line cordinates
START_sideline = sv.Point(198,250)
END_sideline = sv.Point(238,202)


# Store the track history
track_history = defaultdict(lambda: [])

# Create a dictionary to keep track of objects that have crossed the line
crossed_objects_main = {}
crossed_objects_sideline = {}

# Open a video sink for the output video
video_info = sv.VideoInfo.from_video_path("/content/d.mp4")
with sv.VideoSink("output_single_line.mp4", video_info) as sink:

    while cap.isOpened():
        success, frame = cap.read()

        if success:
            # Run YOLOv8 tracking on the frame, persisting tracks between frames
            results = model.track(frame, classes=[2, 3, 5, 7], persist=True, save=True, tracker="bytetrack.yaml")

            # Get the boxes and track IDs
            boxes = results[0].boxes.xywh.cpu()
            track_ids = results[0].boxes.id.int().cpu().tolist()

            # Visualize the results on the frame
            annotated_frame = results[0].plot()
            detections = sv.Detections.from_ultralytics(results[0])

            # Plot the tracks and count objects crossing the line
            for box, track_id in zip(boxes, track_ids):
                x, y, w, h = box
                track = track_history[track_id]
                track.append((float(x), float(y)))  # x, y center point
                if len(track) > 30:  # retain 30 tracks for 30 frames
                    track.pop(0)

                # Check if the object crosses the line
                if START.x < x < END.x and abs(y - START.y) < 5:  # Assuming objects cross horizontally
                    if track_id not in crossed_objects_main:
                        crossed_objects_main[track_id] = True
                if START_sideline.x < x < END_sideline.x and min(START_sideline.y,END_sideline.y)<y<max(START_sideline.y,END_sideline.y) :  # Assuming objects cross horizontally
                    if track_id not in crossed_objects_sideline:
                        crossed_objects_sideline[track_id] = True

                    # Annotate the object as it crosses the line
                    cv2.rectangle(annotated_frame, (int(x - w / 2), int(y - h / 2)), (int(x + w / 2), int(y + h / 2)), (0, 255, 0), 2)

            # Draw the line on the frame
            cv2.line(annotated_frame, (START.x, START.y), (END.x, END.y), (0, 255, 0), 2)
            cv2.line(annotated_frame, (START_sideline.x, START_sideline.y), (END_sideline.x, END_sideline.y), (0, 0, 255), 2)

            # Write the count of objects on each frame
            count_main_text = f"Objects Main crossed: {len(crossed_objects_main)}"
            count_sideline_text = f"Objects sideline crossed: {len(crossed_objects_sideline)}"
            cv2.putText(annotated_frame, count_main_text, (10, 20), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
            cv2.putText(annotated_frame, count_sideline_text, (40, 60), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

            # Write the frame with annotations to the output video
            sink.write_frame(annotated_frame)
        else:
            break

# Release the video capture
cap.release()
# Out:
# 0: 384x640 7 cars, 130.7ms
# Speed: 1.6ms preprocess, 130.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track6
#
# 0: 384x640 7 cars, 102.4ms
# Speed: 1.7ms preprocess, 102.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track6
#
# 0: 384x640 7 cars, 117.6ms
# Speed: 1.3ms preprocess, 117.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track6
#
# 0: 384x640 7 cars, 161.0ms
# Speed: 1.4ms preprocess, 161.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track6
#
# 0: 384x640 7 cars, 144.1ms
# Speed: 1.3ms preprocess, 144.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track6
#
# 0: 384x640 7 cars, 131.1ms
# Speed: 1.3ms preprocess, 131.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# ...
